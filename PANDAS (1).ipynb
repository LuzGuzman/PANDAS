# %% [markdown]
# #**PANDAS**
# ###IMPORTANDO LA BASE

# %%
import pandas as pd
url="https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv"
pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %% [markdown]
# Vemos que esta separado por ;

# %%
datos=pd.read_csv(url, sep=";")
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.sample(10)
# Out:
#                           Tipo     Colonia  Habitaciones  Garages  Suites  \
# 15492             Tienda/Salón   Iztacalco             0        2       0
# 8999              Tienda/Salón    Santa Fe             0        1       0
# 18612  Conjunto Comercial/Sala    Santa Fe             0        1       0
# 10147             Departamento    Santa Fe             2        1       1
# 24815             Departamento     Tlalpan             1        0       0
# 21046             Departamento    Santa Fe             5        3       4
# 9459   Conjunto Comercial/Sala    Narvarte             0        1       0
# 21926             Departamento  Peralvillo             2        1       0
# 10023             Departamento     Condesa             2        0       1
# 21347        Edificio Completo   La Merced             0       89       0
#
#        Area      Valor  Condominio  Impuesto
# 15492   100    21000.0       910.0       NaN
# 8999     80    28350.0    109018.0       NaN
# ...

# %% [markdown]
# Pandas ofrece diversas funciones para importar y exportar datos en diferentes formatos. Las principales funciones de Pandas para importar datos son las siguientes:
#
# read_csv(): Esta función se utiliza para leer archivos CSV (Comma Separated Values), que son archivos de texto que contienen datos separados por comas. Es posible proporcionar varios parámetros para personalizar la lectura del CSV, como el delimitador, el encabezado, el tipo de codificación, entre otros.
#
# read_excel(): Esta función se utiliza para leer archivos de Excel (.xls o .xlsx) y crear un DataFrame a partir de los datos.
#
# read_json(): Esta función se utiliza para leer archivos JSON (JavaScript Object Notation), que son archivos de texto que contienen datos en formato de objeto JavaScript.
#
# read_html(): Esta función se utiliza para leer tablas HTML, que son estructuras de datos organizadas en formato de tabla en una página web.
#
# read_sql(): Esta función se utiliza para leer datos de una base de datos relacional, como MySQL, PostgreSQL y SQL Server.

# %% [markdown]
# ###EXPLORACION INICIAL DE LOS DATOS

# %%
datos.shape
# Out:
# (25121, 9)

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos[["Habitaciones","Valor"]]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %%
datos.describe()
# Out:
#        Habitaciones       Garages        Suites          Area         Valor  \
# count  25121.000000  25121.000000  25121.000000  25121.000000  2.510700e+04
# mean       1.748856      1.798655      0.656781    220.885076  3.688505e+04
# std        1.811131     22.906129      1.083180    817.465428  3.669381e+05
# min        0.000000      0.000000      0.000000      0.000000  3.150000e+02
# 25%        0.000000      0.000000      0.000000     55.000000  5.600000e+03
# 50%        2.000000      1.000000      0.000000     90.000000  1.137500e+04
# 75%        3.000000      2.000000      1.000000    180.000000  2.695000e+04
# max      100.000000   1966.000000     24.000000  42000.000000  5.250000e+07
#
#          Condominio      Impuesto
# count  2.249500e+04  1.803700e+04
# mean   9.528676e+03  4.436513e+03
# std    1.547102e+05  2.283381e+04
# min    3.500000e+00  3.500000e+00
# 25%    2.275000e+03  4.270000e+02
# 50%    4.056500e+03  1.008000e+03
# 75%    7.350000e+03  2.625000e+03
# ...

# %%
datos["Valor"].mean()
# Out:
# np.float64(36885.05048392878)

# %% [markdown]
# GROUPBY

# %%
datos.groupby("Tipo").mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %% [markdown]
# Si queremos el promedio solo de la columna valor

# %%
datos.groupby("Tipo")["Valor"].mean(numeric_only=True)
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
df_tipoPrecio=datos.groupby("Tipo")[["Valor"]].mean().sort_values("Valor")
#ponemos doble corchete para dar formato de dataframe
df_tipoPrecio.plot(kind="barh",figsize=(12,8),color="red")
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# Este método tiene varios parámetros, algunos de los cuales son:
#
# by: Este es el parámetro más común y se utiliza para especificar la columna o columnas por las cuales queremos agrupar. Como argumento, podemos pasar el nombre de una columna o una lista de nombres de columnas;
#
# axis: Utilizamos este parámetro para especificar el eje a lo largo del cual queremos agrupar. El valor predeterminado es 0, lo que significa que se agruparán las filas. Si deseamos agrupar las columnas, debemos establecer este parámetro en 1;
#
# sort: Este parámetro es un booleano (True o False) que indica si los grupos deben ordenarse por el valor de la columna de agrupación. El valor predeterminado es True;
#
# dropna: Utilizamos este parámetro para controlar si los valores faltantes (NaN) se eliminarán o no durante el proceso de agrupación. El valor predeterminado es True.

# %%
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón', 'Casa Comercial',
                         'Terreno Estándar', 'Cochera/Estacionamiento', 'Galpón/Depósito/Almacén',
                         'Tienda en Centro Comercial','Hotel', 'Loteo/Condominio','Industria']

# %%
datos.query("@inmuebles_comerciales in Tipo")
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
df=datos.query("@inmuebles_comerciales not in Tipo")
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
df_tipoPrecio=df.groupby("Tipo")[["Valor"]].mean().sort_values("Valor")
#ponemos doble corchete para dar formato de dataframe
df_tipoPrecio.plot(kind="barh",figsize=(12,8),color="red")
# Out:
# <Axes: ylabel='Tipo'>

# %%
df.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
dpto=df.query("Tipo=='Departamento'")
dpto
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %% [markdown]
# DATOS NULOS

# %%
dpto.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
dpto.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %%
dpto.fillna(0)
#Llenar los datos nulos con 0
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
dpto=dpto.fillna(0)
dpto.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# Eliminar los datos nulos: Es posible eliminar las filas o columnas que contienen valores nulos utilizando el método dropna(). Este método elimina todas las filas o columnas que tienen al menos un valor nulo.
#
# Llenar los datos nulos: Utilizando el método fillna(), podemos llenar los valores nulos con un valor específico. Además, también es posible utilizar argumentos específicos del método fillna(), como method="ffill" o method="bfill", para llenar los valores nulos con el valor anterior o posterior, respectivamente.
#
# Interpolar los datos nulos: Es posible utilizar el método interpolate() para llenar los valores nulos con valores interpolados, es decir, valores calculados a partir de los valores vecinos.

# %% [markdown]
# Datos inconsistentes

# %%
dpto.query('Valor==0 | Condominio==0')
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
dpto.query('Valor==0 | Condominio==0').index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
df_remover=dpto.query('Valor==0 | Condominio==0').index
dpto.drop(df_remover,axis=0,inplace=True)
dpto.query('Valor==0 | Condominio==0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Colonia, Habitaciones, Garages, Suites, Area, Valor, Condominio, Impuesto]
# Index: []

# %% [markdown]
# Quitamos la columna de tipo (siempre son departamentos entonces no es necesaria)

# %%
dpto.drop("Tipo",axis=1,inplace=True)

# %%
dpto.sample(10)
# Out:
#                       Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 4688                 Santa Fe             1        1       1    70  12250.0
# 21737                 Condesa             1        0       0    50   7700.0
# 13083               Del Valle             3        0       0    80   6300.0
# 9792                 Narvarte             2        0       0    70   4550.0
# 23475                 Condesa             3        0       2   116  13650.0
# 844                  Narvarte             3        0       0    80   5600.0
# 21959                Coyoacán             2        1       0    67  10150.0
# 18483              Peralvillo             2        1       0    66   3850.0
# 853    San Miguel Chapultepec             2        1       1    70   5250.0
# 25105                Santa Fe             2        1       1    85   7875.0
#
#        Condominio  Impuesto
# 4688       3675.0       3.5
# 21737      1606.5     276.5
# 13083      3430.0     360.5
# ...

# %% [markdown]
# FILTROS

# %%
#Apartamentos que tiene un dormitorio y un alquiler menor a 4200
seleccion1=dpto["Habitaciones"]==1
#seleccion1 se convierte en una serie de pandas
dpto[seleccion1]
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 19                 Narvarte             1        0       0    48   2625.0
# 37         Centro Histórico             1        0       0    27   2625.0
# ...                     ...           ...      ...     ...   ...      ...
# 25090              Coyoacán             1        0       0    55   7000.0
# 25092              Santa Fe             1        1       0    62   5950.0
# 25100  Lomas de Chapultepec             1        1       1    50  15050.0
# 25103               Condesa             1        0       0    50   6825.0
# 25114              Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
seleccion2=dpto["Valor"]< 4200
dpto[seleccion2]
# Out:
#                   Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3        Centro Histórico             1        0       0    15  2800.0
# 4               Del Valle             1        0       0    48  2800.0
# 19               Narvarte             1        0       0    48  2625.0
# 37       Centro Histórico             1        0       0    27  2625.0
# 61       Centro Histórico             1        1       0    37  3850.0
# ...                   ...           ...      ...     ...   ...     ...
# 25038  Villa de Guadalupe             2        1       0    50  2800.0
# 25051           Nativitas             2        1       0    62  3500.0
# 25065           Nativitas             2        1       0    50  3150.0
# 25095      Lindavista Sur             2        0       0    63  2800.0
# 25114            Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# ...

# %%
filtro1=(seleccion1)&(seleccion2)
dpto[filtro1]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
#Apartamentos que tiene al menos dos dormitorios, un alquiler menor a 10500 y una superficie mayor a 70 m2
query1=dpto["Habitaciones"]>=2
query2=dpto['Valor']<10500
query3=dpto['Area']>70
filtro2=(query1)&(query2)&(query3)
dpto[filtro2]
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %% [markdown]
# # GUARDANDO LOS ARCHIVOS

# %%
df1=dpto[filtro1]
df2=dpto[filtro2]

# %%
dpto.to_csv("Departametos.csv",index=False)
#quitamos la columna de indice que se crea por defecto

# %%
pd.read_csv("Departametos.csv")
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 0          Centro Histórico             1        0       0    15   2800.0
# 1                 Del Valle             1        0       0    48   2800.0
# 2                   Condesa             1        0       1    40   7000.0
# 3                   Condesa             4        3       1   243  45500.0
# 4                  Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 14259  Lomas de Chapultepec             3        0       1    80  10500.0
# 14260              Coyoacán             3        1       2   150  52500.0
# 14261              Narvarte             1        0       0    28   3500.0
# 14262               Mixcoac             2        1       0    48   4900.0
# 14263  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 0          1365.0      70.0
# ...

# %%
dpto.to_csv("Departametos.csv",index=False,sep=";")
#cambiamos el separador

# %%
df1.to_csv("Filtro1.csv",index=False,sep=";")
df2.to_csv("Filtro2.csv",index=False,sep=";")
#cada que abramos el cuaderno hay que correr esta celda para que aparezcan a menos que conectemos drive
#y copiemos la ruta

# %% [markdown]
# CREAR COLUMNAS NUMERICAS
# 1. valor_mensual: Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.

# %%
datos=pd.read_csv(url,sep=";")

# %%
datos["Valor_mensual"]=datos["Valor"]+datos["Condominio"]
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %% [markdown]
# 2. valor_anual: Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.

# %%
datos["Valor_anual"]=datos["Valor_mensual"]*12+datos["Impuesto"]
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual
# 25116       0   755  49000.0         NaN       NaN            NaN          NaN
# 25117       0    27   2800.0      1225.0      87.5         4025.0      48387.5
# 25118       0    48   4900.0      1781.5     129.5         6681.5      80307.5
# 25119       0    70  10500.0      2660.0       NaN        13160.0          NaN
# 25120       0   250  22750.0     14721.0    3881.5        37471.0     453533.5

# %% [markdown]
# CREAR COLUMNAS CATEGORICAS

# %% [markdown]
# Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.

# %%
datos["Descripcion"]=datos["Tipo"]+" "+datos["Colonia"]
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                         Descripcion
# 0                  Cocineta Condesa
# ...

# %%
datos['Descripcion'] = datos['Tipo'] + ' en la colonia ' +datos['Colonia'] + \
                        ' con '+ datos['Habitaciones'].astype(str) + ' cuarto(s) y '  + \
                        datos['Garages'].astype(str) + ' plazas de estacionamiento.'
#astype para poder concatenar enteros
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion
# ...

# %%
datos.iloc[500].Descripcion
# Out:
# 'Departamento en la colonia Napoles con 1 cuarto(s) y 0 plazas de estacionamiento.'

# %% [markdown]
# 2. Tiene_suite: Esta debe ser una columna que indique únicamente si la propiedad tiene o no suites, sin importar la cantidad.

# %%
datos["Tiene_suite"]=datos["Suites"].apply(lambda x: "Si" if x>0 else "No")
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion Tiene_suite
# ...

# %% [markdown]
# #LEYENDO ARCHIVOS

# %% [markdown]
# CSV

# %%
datos = pd.read_csv("superstore_data.csv")
datos.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
datos_primeras_lineas = pd.read_csv("superstore_data.csv",nrows=5, usecols=["Id","Income","Response"])
#tambien se puede usecols=[0,4,18] (numero de columnas)
datos_primeras_lineas
# Out:
#       Id  Income  Response
# 0   1826   84835         1
# 1      1   57091         1
# 2  10476   67267         0
# 3   1386   32474         0
# 4   5371   21474         1

# %%
datos_primeras_lineas.to_csv("resumen.csv",index=False)

# %%
seleccion=pd.read_csv("resumen.csv")
seleccion
# Out:
#       Id  Income  Response
# 0   1826   84835         1
# 1      1   57091         1
# 2  10476   67267         0
# 3   1386   32474         0
# 4   5371   21474         1

# %% [markdown]
# ncoding='ISO-8859-1'
# : tipo de codificación de caracteres del archivo. En este caso, es la codificación ISO-8859-1 la que es común en los archivos en idioma portugués.
#
#
# sep=';': separador de los valores del archivo. En este caso, es el punto y coma (;).
#
#
# skiprows=3: indica que las primeras tres líneas del archivo deben ignorarse ya que no contienen datos relevantes.
#
#
# skipfooter=9: Indica que las últimas nueve líneas del archivo deben ignorarse ya que no contienen datos relevantes.
#
#
# engine='python': el motor utilizado para leer el archivo es Python. Esto es necesario cuando se utiliza el parámetro skipfooter, ya que el motor predeterminado no admite esta opción.

# %% [markdown]
# EXCEL

# %%
datos_co2=pd.read_excel("emisiones_CO2.xlsx")
datos_co2
# Out:
#              País ISO 3166-1 alpha-3   Año         Total        Carbón  \
# 0      Afganistán                AFG  1750  0.000000e+00           NaN
# 1      Afganistán                AFG  1751  0.000000e+00           NaN
# 2      Afganistán                AFG  1752  0.000000e+00           NaN
# 3      Afganistán                AFG  1753  0.000000e+00           NaN
# 4      Afganistán                AFG  1754  0.000000e+00           NaN
# ...           ...                ...   ...           ...           ...
# 63099      Global                WLD  2017  3.609674e+10  1.450697e+10
# 63100      Global                WLD  2018  3.682651e+10  1.474683e+10
# 63101      Global                WLD  2019  3.708256e+10  1.472598e+10
# 63102      Global                WLD  2020  3.526409e+10  1.417456e+10
# 63103      Global                WLD  2021  3.712385e+10  1.497960e+10
#
#              Aceite           Gas       Cemento        Quema        Otros  \
# ...

# %%
pd.ExcelFile("emisiones_CO2.xlsx").sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %%
percapita=pd.read_excel("emisiones_CO2.xlsx",sheet_name="emisiones_percapita")
percapita
# Out:
#              País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 0      Afganistán                AFG  1750        NaN        NaN        NaN
# 1      Afganistán                AFG  1751        NaN        NaN        NaN
# 2      Afganistán                AFG  1752        NaN        NaN        NaN
# 3      Afganistán                AFG  1753        NaN        NaN        NaN
# 4      Afganistán                AFG  1754        NaN        NaN        NaN
# ...           ...                ...   ...        ...        ...        ...
# 63099      Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100      Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101      Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102      Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103      Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# ...

# %%
fuentes=pd.read_excel("emisiones_CO2.xlsx",sheet_name="fuentes")
fuentes
# Out:
#              País ISO 3166-1 alpha-3   Año  \
# 0      Afganistán                AFG  1750
# 1      Afganistán                AFG  1751
# 2      Afganistán                AFG  1752
# 3      Afganistán                AFG  1753
# 4      Afganistán                AFG  1754
# ...           ...                ...   ...
# 63099      Global                WLD  2017
# 63100      Global                WLD  2018
# 63101      Global                WLD  2019
# 63102      Global                WLD  2020
# 63103      Global                WLD  2021
#
#                                       Total             Carbón  \
# 0                                    [NONE]             [NONE]
# 1                                    [NONE]             [NONE]
# 2                                    [NONE]             [NONE]
# 3                                    [NONE]             [NONE]
# 4                                    [NONE]             [NONE]
# ...

# %%
intervalo=pd.read_excel("emisiones_CO2.xlsx",sheet_name="emisiones_C02", usecols="A:D",nrows=50)
intervalo
# Out:
#           País ISO 3166-1 alpha-3   Año  Total
# 0   Afganistán                AFG  1750      0
# 1   Afganistán                AFG  1751      0
# 2   Afganistán                AFG  1752      0
# 3   Afganistán                AFG  1753      0
# 4   Afganistán                AFG  1754      0
# 5   Afganistán                AFG  1755      0
# 6   Afganistán                AFG  1756      0
# 7   Afganistán                AFG  1757      0
# 8   Afganistán                AFG  1758      0
# 9   Afganistán                AFG  1759      0
# 10  Afganistán                AFG  1760      0
# 11  Afganistán                AFG  1761      0
# 12  Afganistán                AFG  1762      0
# 13  Afganistán                AFG  1763      0
# 14  Afganistán                AFG  1764      0
# 15  Afganistán                AFG  1765      0
# 16  Afganistán                AFG  1766      0
# 17  Afganistán                AFG  1767      0
# 18  Afganistán                AFG  1768      0
# ...

# %%
intervalo.to_excel("Emisiones_percapita.xlsx",index=False)

# %%
seleccion=pd.read_excel("Emisiones_percapita.xlsx")
seleccion
# Out:
#           País ISO 3166-1 alpha-3   Año  Total
# 0   Afganistán                AFG  1750      0
# 1   Afganistán                AFG  1751      0
# 2   Afganistán                AFG  1752      0
# 3   Afganistán                AFG  1753      0
# 4   Afganistán                AFG  1754      0
# 5   Afganistán                AFG  1755      0
# 6   Afganistán                AFG  1756      0
# 7   Afganistán                AFG  1757      0
# 8   Afganistán                AFG  1758      0
# 9   Afganistán                AFG  1759      0
# 10  Afganistán                AFG  1760      0
# 11  Afganistán                AFG  1761      0
# 12  Afganistán                AFG  1762      0
# 13  Afganistán                AFG  1763      0
# 14  Afganistán                AFG  1764      0
# 15  Afganistán                AFG  1765      0
# 16  Afganistán                AFG  1766      0
# 17  Afganistán                AFG  1767      0
# 18  Afganistán                AFG  1768      0
# ...

# %% [markdown]
# GOOGLE SHEETS

# %%
#https://docs.google.com/spreadsheets/d/1L1CDVkPB43eWER7jrvwPxzCUGBFc-4fhT-3fqIOw-6M/edit?usp=sharing
sheet_id='1L1CDVkPB43eWER7jrvwPxzCUGBFc-4fhT-3fqIOw-6M'
url=f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'
#gviz/tq?tqx=out:csv es una extension para leerlo en google colab y la forma de leerlo, en este caso csv
#si no se especifica la sheet se usa la primera por default

# %%
datos_sheets=pd.read_csv(url)
datos_sheets
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-3138334712.py in <cell line: 0>()
# ----> 1 datos_sheets=pd.read_csv(url)
#       2 datos_sheets
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#Para abrir la segunda hoja
sheet_id='1L1CDVkPB43eWER7jrvwPxzCUGBFc-4fhT-3fqIOw-6M'
url_percapita=f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet=emisiones_percapita'

# %% [markdown]
# JSON

# %%
datos_pacientes=pd.read_json("pacientes.json")
datos_pacientes
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# ...

# %% [markdown]
# Normalizacion para datos anidados

# %%
datos_pacientes2=pd.read_json("pacientes_2.json")
datos_pacientes2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %%
pacientes2_normalizado=pd.json_normalize(datos_pacientes2["Pacientes"])
pacientes2_normalizado
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %%
#Para exportar en json no es necesario ignorar el index
pacientes2_normalizado.to_json("pacientes_normalizado.json")

# %% [markdown]
# HTML y XML

# %%
dtos_html=pd.read_html("peliculas_wikipedia.html")
dtos_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %%
type(dtos_html)
# Out:
# list

# %%
len(dtos_html)
# Out:
# 3

# %%
top_peliculas=dtos_html[1]
top_peliculas
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %%
datos_imdb=pd.read_xml("imdb_top_1000.xml")
datos_imdb
# Out:
#      index                                        Poster_Link  \
# 0        0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1        1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2        2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3        3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4        4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..     ...                                                ...
# 995    995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996    996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997    997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998    998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# ...

# %% [markdown]
# BASE DE DATOS

# %%
import sqlalchemy
from sqlalchemy import table, MetaData, create_engine, inspect, text

# %%
engine=create_engine('sqlite:///:memory:')
#creamos el motor y elegimos la memoria de google colab

# %%
archivo='clientes_banco.csv'
datos_clientes=pd.read_csv(archivo)

# %% [markdown]
# hay que pasar el csv a un dataframe y luego a sql

# %%
datos_clientes.to_sql('clientes',engine,index=False)
# Out:
# 438463

# %%
inspector=inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %%
query='SELECT * FROM clientes WHERE Categoria_de_renta= "Empleado"'

# %%
empleados=pd.read_sql(sql=text(query),con=engine.connect())

# %%
empleados
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
empleados.to_sql('empleados',con=engine.connect(),index=False)
# Out:
# 226059

# %%
pd.read_sql_table('empleados',con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
pd.read_sql_table('empleados',con=engine.connect(),columns=[0,1,2])
# Out:
#         ID_Cliente  Edad     Grado_estudio
# 0          5008804    32    Nivel superior
# 1          5008805    32    Nivel superior
# 2          5008806    58  Nivel intermedio
# 3          5008815    46    Nivel superior
# 4          5112956    46    Nivel superior
# ...            ...   ...               ...
# 226054     6837905    43  Nivel intermedio
# 226055     6837906    43  Nivel intermedio
# 226056     6839936    34  Nivel intermedio
# 226057     6840222    43  Nivel intermedio
# 226058     6842885    51  Nivel intermedio
#
# [226059 rows x 3 columns]

# %%
query='SELECT * FROM clientes'
pd.read_sql(sql=text(query), con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
#borrar registros
from sqlalchemy.exc import SQLAlchemyError

# %%
query='DELETE FROM clientes WHERE ID_Cliente=5008804'
try:
  r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else: print("Numero de registro borrados ", r_set.rowcount)
# Out:
# Numero de registro borrados  1

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52  Nivel intermedio           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
#actualizando registros
query='UPDATE clientes SET Grado_estudio="Nivel superior" WHERE ID_Cliente=5008808'
try:
  r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else: print("Numero de registros actualizados ", r_set.rowcount)
# Out:
# Numero de registros actualizados  1

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52    Nivel superior           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
inspector=inspect(engine)
print(inspector.get_table_names())
# Out:
# ['clientes', 'empleados']

# %%
#insertar registros
query = 'INSERT INTO clientes (ID_Cliente, Edad, Grado_estudio, Estado_civil, ' \
        'Tamaño_familia, Categoria_de_renta, Ocupacion, Años_empleado, ' \
        'Rendimiento_anual, Tiene_carro, Vivienda) ' \
        'VALUES (6850985, 33, "Doctorado", "Soltero", 1, "Empleado", "TI", ' \
        '2, 290000, 0, "Casa/Departamento propio")'

try:
  r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros insertados: ",r_set.rowcount)
# Out:
# #Registros insertados:  1

# %%
pd.read_sql_table('clientes', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52    Nivel superior           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
# 438462     6850985    33         Doctorado           Soltero               1
#
# ...
